# %%
import json

import requests

# %% [markdown]
# # Routing with OTP API

# %%
# Played around with OTP API for routing
url = 'http://localhost:8080/otp/routers/default/plan'
query = {
    "fromPlace":'-36.87927732520206,174.8173713684082',
    "toPlace":'-36.85183998798974,174.76100206375122',
    "time":'8:00am',
    "date":'07-20-2017',
    "mode":'TRANSIT,WALK',
    "maxWalkDistance":'1000',
    "arriveBy":"false",
    "wheelchair":"false",
    "locale":"en"}
    
r = requests.get(url, params=query)
r.json()
# Out:
# {'debugOutput': {'pathCalculationTime': 102,
#   'pathTimes': [41, 35, 26],
#   'precalculationTime': 108,
#   'renderingTime': 0,
#   'timedOut': False,
#   'totalTime': 210},
#  'elevationMetadata': {'ellipsoidToGeoidDifference': 33.9425994462983,
#   'geoidElevation': False},
#  'plan': {'date': 1500494400000,
#   'from': {'lat': -36.87927732520206,
#    'lon': 174.8173713684082,
#    'name': 'Origin',
#    'orig': '',
#    'vertexType': 'NORMAL'},
#   'itineraries': [{'duration': 2938,
#     'elevationGained': 0.0,
#     'elevationLost': 0.0,
#     'endTime': 1500497379000,
#     'legs': [{'agencyTimeZoneOffset': 43200000,
#       'arrivalDelay': 0,
#       'departureDelay': 0,
#       'distance': 104.976,
#       'duration': 83.0,
#       'endTime': 1500494524000,
#       'from': {'departure': 1500494441000,
#        'lat': -36.87927732520206,
#        'lon': 174.8173713684082,
#        'name': 'Origin',
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'interlineWithPreviousLeg': False,
#       'legGeometry': {'length': 3, 'points': 'n~a`Fub_j`@z@?l@tC'},
#       'mode': 'WALK',
#       'pathway': False,
#       'realTime': False,
#       'rentedBike': False,
#       'route': '',
#       'startTime': 1500494441000,
#       'steps': [{'absoluteDirection': 'SOUTH',
#         'area': False,
#         'bogusName': False,
#         'distance': 33.495,
#         'elevation': [],
#         'lat': -36.87927626998918,
#         'lon': 174.81787531421733,
#         'relativeDirection': 'DEPART',
#         'stayOn': False,
#         'streetName': 'Kelvin Road'},
#        {'absoluteDirection': 'WEST',
#         'area': False,
#         'bogusName': False,
#         'distance': 71.481,
#         'elevation': [],
#         'lat': -36.8795775,
#         'lon': 174.8178763,
#         'relativeDirection': 'RIGHT',
#         'stayOn': False,
#         'streetName': 'Remuera Road'}],
#       'to': {'arrival': 1500494524000,
#        'departure': 1500494525000,
#        'lat': -36.87986,
#        'lon': 174.81715,
#        'name': '659 Remuera Rd',
#        'stopCode': '7427',
#        'stopId': '1:7427',
#        'stopIndex': 15,
#        'stopSequence': 16,
#        'vertexType': 'TRANSIT'},
#       'transitLeg': False},
#      {'agencyId': 'NZBML',
#       'agencyName': 'Metrolink',
#       'agencyTimeZoneOffset': 43200000,
#       'agencyUrl': 'http://www.aucklandtransport.govt.nz',
#       'arrivalDelay': 0,
#       'departureDelay': 0,
#       'distance': 6028.862211857214,
#       'duration': 2095.0,
#       'endTime': 1500496620000,
#       'from': {'arrival': 1500494524000,
#        'departure': 1500494525000,
#        'lat': -36.87986,
#        'lon': 174.81715,
#        'name': '659 Remuera Rd',
#        'stopCode': '7427',
#        'stopId': '1:7427',
#        'stopIndex': 15,
#        'stopSequence': 16,
#        'vertexType': 'TRANSIT'},
#       'headsign': 'Britomart',
#       'interlineWithPreviousLeg': False,
#       'legGeometry': {'length': 314,
#        'points': 'bbb`Fe~~i`@IDH`@jA`Gj@rCBN?J?J?J?J?J?JCPGl@ATCRH@IAYhDIz@?NAN?L@L?N@LBJ@NDLBNDLFLBJFPd@z@nAtBDGEF`@p@nD~F@@HNHNDJ@BDHBJBJ@D@D@HBB?JBB?D?BHCIB?B@J@L?L?L?D?@?L?HALARCJCJAHa@|A}@jDMb@AHAHIhAF@GAKfAIdAMhBUdCg@nGYtDJ@KAEx@CZQtEGlAAFS|FEdAIbBEbAALP@QAGhAMvCGnACj@El@Cj@Gd@AVKd@Id@?@JDKECPEPKd@o@tCm@nCi@bC{@|DJDKEWpAQr@CH?FCDCHGLEHGHMJiA`AOJQLMHOFIBcAVo@NMDMDGDGBA@@FAGMHGFGFEHKJILILKVyCjHWl@Qb@IX{@fCELADKXGRHDIEWt@EHCFQ^S\\iA|BkBtDg@`AHFIGg@`AcC|E?@IPu@xAGHFFGGCDEJGFq@v@eFhGs@z@QR?@QRg@l@u@~@IFHJIKKLQTIHCDCDCDCHCHuBe@wCo@YGIAMAG@I?C@I?G?KAEAEVDWC?GAu@WOjAOjA_@`DO~@c@jD_@pCJBKCE\\c@jDk@zE]`C{@~GsBe@OEA??L?MMCwA[oAWiAWKAEAE?E?C?C?A?G@G@u@R}@T_AVWJc@Jo@Pw@Rs@TODq@RIBGDIBCBCDGDGFEHCHAFCHALEVQvACDCNFDGEERC^m@zDObAIz@GRAFADABCFQZS\\GNCDOZQ\\cCvEGPUd@{BjE[j@ELGRy@c@GCEECEkAyA]c@IM??KJ'},
#       'mode': 'BUS',
#       'pathway': False,
#       'realTime': False,
#       'rentedBike': False,
#       'route': '625',
#       'routeId': '1:62501-20170705140526_v55.10',
#       'routeLongName': 'Glen Innes To Britomart Via St Johns And Khyber Pass Rd',
#       'routeShortName': '625',
#       'routeType': 3,
#       'serviceDate': '20170720',
#       'startTime': 1500494525000,
#       'steps': [],
#       'to': {'arrival': 1500496620000,
#        'departure': 1500496621000,
#        'lat': -36.85741,
#        'lon': 174.76449,
#        'name': '83 Symonds St',
#        'stopCode': '7149',
#        'stopId': '1:7149',
#        'stopIndex': 33,
#        'stopSequence': 34,
#        'vertexType': 'TRANSIT'},
#       'transitLeg': True,
#       'tripId': '1:14625064013-20170705140526_v55.10'},
#      {'agencyTimeZoneOffset': 43200000,
#       'arrivalDelay': 0,
#       'departureDelay': 0,
#       'distance': 929.645,
#       'duration': 758.0,
#       'endTime': 1500497379000,
#       'from': {'arrival': 1500496620000,
#        'departure': 1500496621000,
#        'lat': -36.85741,
#        'lon': 174.76449,
#        'name': '83 Symonds St',
#        'stopCode': '7149',
#        'stopId': '1:7149',
#        'stopIndex': 33,
#        'stopSequence': 34,
#        'vertexType': 'TRANSIT'},
#       'interlineWithPreviousLeg': False,
#       'legGeometry': {'length': 70,
#        'points': 'dv}_Fmuti`@]a@MREFAFCJCLETGh@ANEPETOx@WxAAJAFc@tBUfAKEQ@_A]ME_@M_@MMEWIGOME_@KM@{@YEO_A]MEWIc@M?h@?J?D?RE`@CVEPCNEJGNMRIFIJSN[VSNSLMFQHQFSFSDO@u@FSBMDOFIFGFSRCBQVSSAE'},
#       'mode': 'WALK',
#       'pathway': False,
#       'realTime': False,
#       'rentedBike': False,
#       'route': '',
#       'startTime': 1500496621000,
#       'steps': [{'absoluteDirection': 'NORTHEAST',
#         'area': False,
#         'bogusName': False,
#         'distance': 21.666,
#         'elevation': [],
#         'lat': -36.85746150558646,
#         'lon': 174.76455801097964,
#         'relativeDirection': 'DEPART',
#         'stayOn': False,
#         'streetName': 'Symonds Street'},
#        {'absoluteDirection': 'NORTHWEST',
#         'area': False,
#         'bogusName': False,
#         'distance': 257.635,
#         'elevation': [],
#         'lat': -36.85732,
#         'lon': 174.7647254,
#         'relativeDirection': 'LEFT',
#         'stayOn': False,
#         'streetName': 'City Road'},
#        {'absoluteDirection': 'NORTH',
#         'area': False,
#         'bogusName': False,
#         'distance': 291.173,
#         'elevation': [],
#         'lat': -36.8565193,
#         'lon': 174.7620265,
#         'relativeDirection': 'RIGHT',
#         'stayOn': False,
#         'streetName': 'Queen Street'},
#        {'absoluteDirection': 'WEST',
#         'area': False,
#         'bogusName': False,
#         'distance': 341.827,
#         'elevation': [],
#         'lat': -36.8541009,
#         'lon': 174.7631147,
#         'relativeDirection': 'LEFT',
#         'stayOn': False,
#         'streetName': 'Mayoral Drive'},
#        {'absoluteDirection': 'NORTHEAST',
#         'area': False,
#         'bogusName': False,
#         'distance': 17.344,
#         'elevation': [],
#         'lat': -36.8519798,
#         'lon': 174.7609036,
#         'relativeDirection': 'RIGHT',
#         'stayOn': True,
#         'streetName': 'Mayoral Drive'}],
#       'to': {'arrival': 1500497379000,
#        'lat': -36.85183998798974,
#        'lon': 174.76100206375122,
#        'name': 'Destination',
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'transitLeg': False}],
#     'startTime': 1500494441000,
#     'tooSloped': False,
#     'transfers': 0,
#     'transitTime': 2095,
#     'waitingTime': 2,
#     'walkDistance': 1034.8924285626701,
#     'walkLimitExceeded': False,
#     'walkTime': 841},
#    {'duration': 2938,
#     'elevationGained': 0.0,
#     'elevationLost': 0.0,
#     'endTime': 1500497679000,
#     'legs': [{'agencyTimeZoneOffset': 43200000,
#       'arrivalDelay': 0,
#       'departureDelay': 0,
#       'distance': 104.976,
#       'duration': 83.0,
#       'endTime': 1500494824000,
#       'from': {'departure': 1500494741000,
#        'lat': -36.87927732520206,
#        'lon': 174.8173713684082,
#        'name': 'Origin',
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'interlineWithPreviousLeg': False,
#       'legGeometry': {'length': 3, 'points': 'n~a`Fub_j`@z@?l@tC'},
#       'mode': 'WALK',
#       'pathway': False,
#       'realTime': False,
#       'rentedBike': False,
#       'route': '',
#       'startTime': 1500494741000,
#       'steps': [{'absoluteDirection': 'SOUTH',
#         'area': False,
#         'bogusName': False,
#         'distance': 33.495,
#         'elevation': [],
#         'lat': -36.87927626998918,
#         'lon': 174.81787531421733,
#         'relativeDirection': 'DEPART',
#         'stayOn': False,
#         'streetName': 'Kelvin Road'},
#        {'absoluteDirection': 'WEST',
#         'area': False,
#         'bogusName': False,
#         'distance': 71.481,
#         'elevation': [],
#         'lat': -36.8795775,
#         'lon': 174.8178763,
#         'relativeDirection': 'RIGHT',
#         'stayOn': False,
#         'streetName': 'Remuera Road'}],
#       'to': {'arrival': 1500494824000,
#        'departure': 1500494825000,
#        'lat': -36.87986,
#        'lon': 174.81715,
#        'name': '659 Remuera Rd',
#        'stopCode': '7427',
#        'stopId': '1:7427',
#        'stopIndex': 15,
#        'stopSequence': 16,
#        'vertexType': 'TRANSIT'},
#       'transitLeg': False},
#      {'agencyId': 'NZBML',
#       'agencyName': 'Metrolink',
#       'agencyTimeZoneOffset': 43200000,
#       'agencyUrl': 'http://www.aucklandtransport.govt.nz',
#       'arrivalDelay': 0,
#       'departureDelay': 0,
#       'distance': 6028.862211857214,
#       'duration': 2095.0,
#       'endTime': 1500496920000,
#       'from': {'arrival': 1500494824000,
#        'departure': 1500494825000,
#        'lat': -36.87986,
#        'lon': 174.81715,
#        'name': '659 Remuera Rd',
#        'stopCode': '7427',
#        'stopId': '1:7427',
#        'stopIndex': 15,
#        'stopSequence': 16,
#        'vertexType': 'TRANSIT'},
#       'headsign': 'Britomart',
#       'interlineWithPreviousLeg': False,
#       'legGeometry': {'length': 314,
#        'points': 'bbb`Fe~~i`@IDH`@jA`Gj@rCBN?J?J?J?J?J?JCPGl@ATCRH@IAYhDIz@?NAN?L@L?N@LBJ@NDLBNDLFLBJFPd@z@nAtBDGEF`@p@nD~F@@HNHNDJ@BDHBJBJ@D@D@HBB?JBB?D?BHCIB?B@J@L?L?L?D?@?L?HALARCJCJAHa@|A}@jDMb@AHAHIhAF@GAKfAIdAMhBUdCg@nGYtDJ@KAEx@CZQtEGlAAFS|FEdAIbBEbAALP@QAGhAMvCGnACj@El@Cj@Gd@AVKd@Id@?@JDKECPEPKd@o@tCm@nCi@bC{@|DJDKEWpAQr@CH?FCDCHGLEHGHMJiA`AOJQLMHOFIBcAVo@NMDMDGDGBA@@FAGMHGFGFEHKJILILKVyCjHWl@Qb@IX{@fCELADKXGRHDIEWt@EHCFQ^S\\iA|BkBtDg@`AHFIGg@`AcC|E?@IPu@xAGHFFGGCDEJGFq@v@eFhGs@z@QR?@QRg@l@u@~@IFHJIKKLQTIHCDCDCDCHCHuBe@wCo@YGIAMAG@I?C@I?G?KAEAEVDWC?GAu@WOjAOjA_@`DO~@c@jD_@pCJBKCE\\c@jDk@zE]`C{@~GsBe@OEA??L?MMCwA[oAWiAWKAEAE?E?C?C?A?G@G@u@R}@T_AVWJc@Jo@Pw@Rs@TODq@RIBGDIBCBCDGDGFEHCHAFCHALEVQvACDCNFDGEERC^m@zDObAIz@GRAFADABCFQZS\\GNCDOZQ\\cCvEGPUd@{BjE[j@ELGRy@c@GCEECEkAyA]c@IM??KJ'},
#       'mode': 'BUS',
#       'pathway': False,
#       'realTime': False,
#       'rentedBike': False,
#       'route': '625',
#       'routeId': '1:62501-20170705140526_v55.10',
#       'routeLongName': 'Glen Innes To Britomart Via St Johns And Khyber Pass Rd',
#       'routeShortName': '625',
#       'routeType': 3,
#       'serviceDate': '20170720',
#       'startTime': 1500494825000,
#       'steps': [],
#       'to': {'arrival': 1500496920000,
#        'departure': 1500496921000,
#        'lat': -36.85741,
#        'lon': 174.76449,
#        'name': '83 Symonds St',
#        'stopCode': '7149',
#        'stopId': '1:7149',
#        'stopIndex': 33,
#        'stopSequence': 34,
#        'vertexType': 'TRANSIT'},
#       'transitLeg': True,
#       'tripId': '1:14625064014-20170705140526_v55.10'},
#      {'agencyTimeZoneOffset': 43200000,
#       'arrivalDelay': 0,
#       'departureDelay': 0,
#       'distance': 929.645,
#       'duration': 758.0,
#       'endTime': 1500497679000,
#       'from': {'arrival': 1500496920000,
#        'departure': 1500496921000,
#        'lat': -36.85741,
#        'lon': 174.76449,
#        'name': '83 Symonds St',
#        'stopCode': '7149',
#        'stopId': '1:7149',
#        'stopIndex': 33,
#        'stopSequence': 34,
#        'vertexType': 'TRANSIT'},
#       'interlineWithPreviousLeg': False,
#       'legGeometry': {'length': 70,
#        'points': 'dv}_Fmuti`@]a@MREFAFCJCLETGh@ANEPETOx@WxAAJAFc@tBUfAKEQ@_A]ME_@M_@MMEWIGOME_@KM@{@YEO_A]MEWIc@M?h@?J?D?RE`@CVEPCNEJGNMRIFIJSN[VSNSLMFQHQFSFSDO@u@FSBMDOFIFGFSRCBQVSSAE'},
#       'mode': 'WALK',
#       'pathway': False,
#       'realTime': False,
#       'rentedBike': False,
#       'route': '',
#       'startTime': 1500496921000,
#       'steps': [{'absoluteDirection': 'NORTHEAST',
#         'area': False,
#         'bogusName': False,
#         'distance': 21.666,
#         'elevation': [],
#         'lat': -36.85746150558646,
#         'lon': 174.76455801097964,
#         'relativeDirection': 'DEPART',
#         'stayOn': False,
#         'streetName': 'Symonds Street'},
#        {'absoluteDirection': 'NORTHWEST',
#         'area': False,
#         'bogusName': False,
#         'distance': 257.635,
#         'elevation': [],
#         'lat': -36.85732,
#         'lon': 174.7647254,
#         'relativeDirection': 'LEFT',
#         'stayOn': False,
#         'streetName': 'City Road'},
#        {'absoluteDirection': 'NORTH',
#         'area': False,
#         'bogusName': False,
#         'distance': 291.173,
#         'elevation': [],
#         'lat': -36.8565193,
#         'lon': 174.7620265,
#         'relativeDirection': 'RIGHT',
#         'stayOn': False,
#         'streetName': 'Queen Street'},
#        {'absoluteDirection': 'WEST',
#         'area': False,
#         'bogusName': False,
#         'distance': 341.827,
#         'elevation': [],
#         'lat': -36.8541009,
#         'lon': 174.7631147,
#         'relativeDirection': 'LEFT',
#         'stayOn': False,
#         'streetName': 'Mayoral Drive'},
#        {'absoluteDirection': 'NORTHEAST',
#         'area': False,
#         'bogusName': False,
#         'distance': 17.344,
#         'elevation': [],
#         'lat': -36.8519798,
#         'lon': 174.7609036,
#         'relativeDirection': 'RIGHT',
#         'stayOn': True,
#         'streetName': 'Mayoral Drive'}],
#       'to': {'arrival': 1500497679000,
#        'lat': -36.85183998798974,
#        'lon': 174.76100206375122,
#        'name': 'Destination',
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'transitLeg': False}],
#     'startTime': 1500494741000,
#     'tooSloped': False,
#     'transfers': 0,
#     'transitTime': 2095,
#     'waitingTime': 2,
#     'walkDistance': 1034.8924285626701,
#     'walkLimitExceeded': False,
#     'walkTime': 841},
#    {'duration': 2938,
#     'elevationGained': 0.0,
#     'elevationLost': 0.0,
#     'endTime': 1500497859000,
#     'legs': [{'agencyTimeZoneOffset': 43200000,
#       'arrivalDelay': 0,
#       'departureDelay': 0,
#       'distance': 104.976,
#       'duration': 83.0,
#       'endTime': 1500495004000,
#       'from': {'departure': 1500494921000,
#        'lat': -36.87927732520206,
#        'lon': 174.8173713684082,
#        'name': 'Origin',
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'interlineWithPreviousLeg': False,
#       'legGeometry': {'length': 3, 'points': 'n~a`Fub_j`@z@?l@tC'},
#       'mode': 'WALK',
#       'pathway': False,
#       'realTime': False,
#       'rentedBike': False,
#       'route': '',
#       'startTime': 1500494921000,
#       'steps': [{'absoluteDirection': 'SOUTH',
#         'area': False,
#         'bogusName': False,
#         'distance': 33.495,
#         'elevation': [],
#         'lat': -36.87927626998918,
#         'lon': 174.81787531421733,
#         'relativeDirection': 'DEPART',
#         'stayOn': False,
#         'streetName': 'Kelvin Road'},
#        {'absoluteDirection': 'WEST',
#         'area': False,
#         'bogusName': False,
#         'distance': 71.481,
#         'elevation': [],
#         'lat': -36.8795775,
#         'lon': 174.8178763,
#         'relativeDirection': 'RIGHT',
#         'stayOn': False,
#         'streetName': 'Remuera Road'}],
#       'to': {'arrival': 1500495004000,
#        'departure': 1500495005000,
#        'lat': -36.87986,
#        'lon': 174.81715,
#        'name': '659 Remuera Rd',
#        'stopCode': '7427',
#        'stopId': '1:7427',
#        'stopIndex': 15,
#        'stopSequence': 16,
#        'vertexType': 'TRANSIT'},
#       'transitLeg': False},
#      {'agencyId': 'NZBML',
#       'agencyName': 'Metrolink',
#       'agencyTimeZoneOffset': 43200000,
#       'agencyUrl': 'http://www.aucklandtransport.govt.nz',
#       'arrivalDelay': 0,
#       'departureDelay': 0,
#       'distance': 6028.862211857214,
#       'duration': 2095.0,
#       'endTime': 1500497100000,
#       'from': {'arrival': 1500495004000,
#        'departure': 1500495005000,
#        'lat': -36.87986,
#        'lon': 174.81715,
#        'name': '659 Remuera Rd',
#        'stopCode': '7427',
#        'stopId': '1:7427',
#        'stopIndex': 15,
#        'stopSequence': 16,
#        'vertexType': 'TRANSIT'},
#       'headsign': 'Britomart',
#       'interlineWithPreviousLeg': False,
#       'legGeometry': {'length': 314,
#        'points': 'bbb`Fe~~i`@IDH`@jA`Gj@rCBN?J?J?J?J?J?JCPGl@ATCRH@IAYhDIz@?NAN?L@L?N@LBJ@NDLBNDLFLBJFPd@z@nAtBDGEF`@p@nD~F@@HNHNDJ@BDHBJBJ@D@D@HBB?JBB?D?BHCIB?B@J@L?L?L?D?@?L?HALARCJCJAHa@|A}@jDMb@AHAHIhAF@GAKfAIdAMhBUdCg@nGYtDJ@KAEx@CZQtEGlAAFS|FEdAIbBEbAALP@QAGhAMvCGnACj@El@Cj@Gd@AVKd@Id@?@JDKECPEPKd@o@tCm@nCi@bC{@|DJDKEWpAQr@CH?FCDCHGLEHGHMJiA`AOJQLMHOFIBcAVo@NMDMDGDGBA@@FAGMHGFGFEHKJILILKVyCjHWl@Qb@IX{@fCELADKXGRHDIEWt@EHCFQ^S\\iA|BkBtDg@`AHFIGg@`AcC|E?@IPu@xAGHFFGGCDEJGFq@v@eFhGs@z@QR?@QRg@l@u@~@IFHJIKKLQTIHCDCDCDCHCHuBe@wCo@YGIAMAG@I?C@I?G?KAEAEVDWC?GAu@WOjAOjA_@`DO~@c@jD_@pCJBKCE\\c@jDk@zE]`C{@~GsBe@OEA??L?MMCwA[oAWiAWKAEAE?E?C?C?A?G@G@u@R}@T_AVWJc@Jo@Pw@Rs@TODq@RIBGDIBCBCDGDGFEHCHAFCHALEVQvACDCNFDGEERC^m@zDObAIz@GRAFADABCFQZS\\GNCDOZQ\\cCvEGPUd@{BjE[j@ELGRy@c@GCEECEkAyA]c@IM??KJ'},
#       'mode': 'BUS',
#       'pathway': False,
#       'realTime': False,
#       'rentedBike': False,
#       'route': '625',
#       'routeId': '1:62501-20170705140526_v55.10',
#       'routeLongName': 'Glen Innes To Britomart Via St Johns And Khyber Pass Rd',
#       'routeShortName': '625',
#       'routeType': 3,
#       'serviceDate': '20170720',
#       'startTime': 1500495005000,
#       'steps': [],
#       'to': {'arrival': 1500497100000,
#        'departure': 1500497101000,
#        'lat': -36.85741,
#        'lon': 174.76449,
#        'name': '83 Symonds St',
#        'stopCode': '7149',
#        'stopId': '1:7149',
#        'stopIndex': 33,
#        'stopSequence': 34,
#        'vertexType': 'TRANSIT'},
#       'transitLeg': True,
#       'tripId': '1:14625064016-20170705140526_v55.10'},
#      {'agencyTimeZoneOffset': 43200000,
#       'arrivalDelay': 0,
#       'departureDelay': 0,
#       'distance': 929.645,
#       'duration': 758.0,
#       'endTime': 1500497859000,
#       'from': {'arrival': 1500497100000,
#        'departure': 1500497101000,
#        'lat': -36.85741,
#        'lon': 174.76449,
#        'name': '83 Symonds St',
#        'stopCode': '7149',
#        'stopId': '1:7149',
#        'stopIndex': 33,
#        'stopSequence': 34,
#        'vertexType': 'TRANSIT'},
#       'interlineWithPreviousLeg': False,
#       'legGeometry': {'length': 70,
#        'points': 'dv}_Fmuti`@]a@MREFAFCJCLETGh@ANEPETOx@WxAAJAFc@tBUfAKEQ@_A]ME_@M_@MMEWIGOME_@KM@{@YEO_A]MEWIc@M?h@?J?D?RE`@CVEPCNEJGNMRIFIJSN[VSNSLMFQHQFSFSDO@u@FSBMDOFIFGFSRCBQVSSAE'},
#       'mode': 'WALK',
#       'pathway': False,
#       'realTime': False,
#       'rentedBike': False,
#       'route': '',
#       'startTime': 1500497101000,
#       'steps': [{'absoluteDirection': 'NORTHEAST',
#         'area': False,
#         'bogusName': False,
#         'distance': 21.666,
#         'elevation': [],
#         'lat': -36.85746150558646,
#         'lon': 174.76455801097964,
#         'relativeDirection': 'DEPART',
#         'stayOn': False,
#         'streetName': 'Symonds Street'},
#        {'absoluteDirection': 'NORTHWEST',
#         'area': False,
#         'bogusName': False,
#         'distance': 257.635,
#         'elevation': [],
#         'lat': -36.85732,
#         'lon': 174.7647254,
#         'relativeDirection': 'LEFT',
#         'stayOn': False,
#         'streetName': 'City Road'},
#        {'absoluteDirection': 'NORTH',
#         'area': False,
#         'bogusName': False,
#         'distance': 291.173,
#         'elevation': [],
#         'lat': -36.8565193,
#         'lon': 174.7620265,
#         'relativeDirection': 'RIGHT',
#         'stayOn': False,
#         'streetName': 'Queen Street'},
#        {'absoluteDirection': 'WEST',
#         'area': False,
#         'bogusName': False,
#         'distance': 341.827,
#         'elevation': [],
#         'lat': -36.8541009,
#         'lon': 174.7631147,
#         'relativeDirection': 'LEFT',
#         'stayOn': False,
#         'streetName': 'Mayoral Drive'},
#        {'absoluteDirection': 'NORTHEAST',
#         'area': False,
#         'bogusName': False,
#         'distance': 17.344,
#         'elevation': [],
#         'lat': -36.8519798,
#         'lon': 174.7609036,
#         'relativeDirection': 'RIGHT',
#         'stayOn': True,
#         'streetName': 'Mayoral Drive'}],
#       'to': {'arrival': 1500497859000,
#        'lat': -36.85183998798974,
#        'lon': 174.76100206375122,
#        'name': 'Destination',
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'transitLeg': False}],
#     'startTime': 1500494921000,
#     'tooSloped': False,
#     'transfers': 0,
#     'transitTime': 2095,
#     'waitingTime': 2,
#     'walkDistance': 1034.8924285626701,
#     'walkLimitExceeded': False,
#     'walkTime': 841}],
#   'to': {'lat': -36.85183998798974,
#    'lon': 174.76100206375122,
#    'name': 'Destination',
#    'orig': '',
#    'vertexType': 'NORMAL'}},
#  'requestParameters': {'arriveBy': 'false',
#   'date': '07-20-2017',
#   'fromPlace': '-36.87927732520206,174.8173713684082',
#   'locale': 'en',
#   'maxWalkDistance': '1000',
#   'mode': 'TRANSIT,WALK',
#   'time': '8:00am',
#   'toPlace': '-36.85183998798974,174.76100206375122',
#   'wheelchair': 'false'}}

# %% [markdown]
# # Isochrone with OTP API

# %%
# Played around with OTP API for routing
url = 'http://localhost:8080/otp/routers/default/isochrone'
query = {
    "fromPlace":'-36.87845344732706,174.81805801391602',
    "time":'8:00am',
    "date":'07-20-2017',
    "mode":'TRANSIT,WALK',
    "cutoffSec":[300, 600]}
    
r = requests.get(url, params=query)
r.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[[174.82, -36.8769],
#        [174.82, -36.8767],
#        [174.8194, -36.8756],
#        [174.8194, -36.8749],
#        [174.8188, -36.8742],
#        [174.8181, -36.8733],
#        [174.8178, -36.8733],
#        [174.8158, -36.8747],
#        [174.8156, -36.8749],
#        [174.8156, -36.875],
#        [174.8152, -36.8767],
#        [174.8151, -36.8772],
#        [174.8142, -36.8785],
#        [174.8136, -36.8794],
#        [174.812, -36.8797],
#        [174.8113, -36.8791],
#        [174.8094, -36.8803],
#        [174.8091, -36.8805],
#        [174.8087, -36.8805],
#        [174.8068, -36.8812],
#        [174.8059, -36.8821],
#        [174.8065, -36.8823],
#        [174.8068, -36.8829],
#        [174.8074, -36.8833],
#        [174.8091, -36.8837],
#        [174.8106, -36.8821],
#        [174.8113, -36.8812],
#        [174.8119, -36.8816],
#        [174.8136, -36.8815],
#        [174.814, -36.8817],
#        [174.8158, -36.8818],
#        [174.816, -36.8819],
#        [174.817, -36.8821],
#        [174.8164, -36.8833],
#        [174.8181, -36.8824],
#        [174.8196, -36.8821],
#        [174.8203, -36.882],
#        [174.8221, -36.8803],
#        [174.8226, -36.8792],
#        [174.8238, -36.8792],
#        [174.8248, -36.8798],
#        [174.8259, -36.8785],
#        [174.8267, -36.8769],
#        [174.827, -36.8767],
#        [174.8265, -36.8753],
#        [174.8248, -36.8749],
#        [174.8249, -36.8748],
#        [174.8248, -36.8731],
#        [174.8227, -36.8749],
#        [174.8227, -36.8766],
#        [174.8227, -36.8767],
#        [174.8226, -36.8768],
#        [174.8222, -36.877],
#        [174.8203, -36.8772],
#        [174.82, -36.8769]]],
#      [[[174.8281, -36.8741],
#        [174.8293, -36.8742],
#        [174.8307, -36.8738],
#        [174.8315, -36.8734],
#        [174.8334, -36.8734],
#        [174.8338, -36.8734],
#        [174.8352, -36.8737],
#        [174.836, -36.8739],
#        [174.8374, -36.8731],
#        [174.838, -36.8715],
#        [174.836, -36.8723],
#        [174.8343, -36.8727],
#        [174.8338, -36.8726],
#        [174.8322, -36.8725],
#        [174.8315, -36.8724],
#        [174.8306, -36.872],
#        [174.8293, -36.8723],
#        [174.8277, -36.8731],
#        [174.8281, -36.8741]]]],
#     'type': 'MultiPolygon'},
#    'id': 'fid--44aef973_15e082d778a_-7fff',
#    'properties': {'time': 600},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [], 'type': 'MultiPolygon'},
#    'id': 'fid--44aef973_15e082d778a_-8000',
#    'properties': {'time': 300},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Played around with OTP API for routing
url = 'http://localhost:8080/otp/surfaces'
query = {
    "fromPlace":'-36.87845344732706,174.81805801391602',
    "toPlace":'-36.87845344732706,174.81805801391602',
    "time":'8:00am',
    "date":'07-20-2017',
    "mode":'TRANSIT,WALK',
    "maxWalkDistance":'1000',
    "batch": 'true',
    "layers":'traveltime',
    "styles":'color30'}
    
r = requests.get(url, params=query)
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# [{'id': 0,
#   'params': {'batch': 'true',
#    'date': '08-22-2017',
#    'fromPlace': '-36.86935587159934,174.75904941558838',
#    'layers': 'traveltime',
#    'maxWalkDistance': '804.672',
#    'mode': 'TRANSIT,WALK',
#    'styles': 'color30',
#    'time': '4:18pm',
#    'toPlace': '-36.86935587159934,174.75904941558838'}},
#  {'id': 1,
#   'params': {'batch': 'true',
#    'date': '07-20-2017',
#    'fromPlace': '-36.86935587159934,174.75904941558838',
#    'layers': 'traveltime',
#    'maxWalkDistance': '804.672',
#    'mode': 'TRANSIT,WALK',
#    'styles': 'color30',
#    'time': '8:00am',
#    'toPlace': '-36.86935587159934,174.75904941558838'}}]
